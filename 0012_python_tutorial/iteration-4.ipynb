# %% [markdown]
# ![logo](python_logo.jpg)

# %%
import pandas as pd

# %%
from pandas import Series

# %%
data = pd.read_csv('test_full_data.csv')
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket dataset_name
# 0       3    male      1       0.0         A/5 21171        train
# 1       1  female      1       1.0          PC 17599        train
# 2       3  female      0       1.0  STON/O2. 3101282        train
# 3       1  female      1       1.0            113803        train
# 4       3    male      0       0.0            373450        train

# %% [markdown]
# # 观察数据

# %%
data.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket dataset_name
# 0       3    male      1       0.0         A/5 21171        train
# 1       1  female      1       1.0          PC 17599        train
# 2       3  female      0       1.0  STON/O2. 3101282        train
# 3       1  female      1       1.0            113803        train
# 4       3    male      0       0.0            373450        train

# %% [markdown]
# 观察数据类型

# %%
dtype = data.dtypes
dtype
# Out:
# Age             float64
# Cabin            object
# Embarked         object
# Fare            float64
# Name             object
# Parch             int64
# PassengerId       int64
# Pclass            int64
# Sex              object
# SibSp             int64
# Survived        float64
# Ticket           object
# dataset_name     object
# dtype: object

# %% [markdown]
# 观察数据，提出假设，验证假设

# %% [markdown]
# 通过少量数据， 我们可以观察到数据的不少特点，并且设计下一步数据清洗和处理的方案
#
# 1. PassengerId可能是和passenger一一对应的编号，它的数值本身无特别意义
# 2. Survived, Class尽管被识别成了数值，但是可能只是分类变量， 数值大小无特别意义。可以读取的时候当做字符处理。
# 3. Name包含姓, 称号， 名，可能会额外的在括号中补充别的信息
# 4. Ticket包含一段字符和一串数字， 字符不一定有； 如果有的话，用空格分割
# 5. Cabin中如果非空， 取值包含一个首字母和数字
# 6. 其他(大家请补充)...
#
#
#
# 当然从5行数据观察到的特点，不一定能代表所有数据的情况。但是会启发我们下一步怎么做。

# %% [markdown]
# 针对第1, 2两点，为了确定每一列的数据到底是数值还是分类， 我想到的策略是:
#
# 计算每一列去重以后取值的个数， 一般来说，分类型特征去重以后取值的个数会远小于样本的数量。
#
# 而唯一的取值id一般和数据行一一对应， 所以数量会和样本数量一致。

# %%
for column_name in data.select_dtypes(include=['number']).columns: 
    print(column_name)
    print(data[column_name].nunique())
    print('--------------------')
# Out:
# Age
# 98
# --------------------
# Fare
# 281
# --------------------
# Parch
# 8
# --------------------
# PassengerId
# 1309
# --------------------
# Pclass
# 3
# --------------------
# SibSp
# 7
# --------------------
# Survived
# 2
# --------------------

# %% [markdown]
# 这里我们可以看到，Survived, Pclass, sibSp, Parch可能只是用不同的数值代表不同的分类，数值大小并无特别意义。而自动id一般没有分析的意义。
#
# 我们可以指定数据类型后重新读取数据。

# %%
data = pd.read_csv('test_full_data.csv', dtype={'Survived':str, 'Pclass':str, 'SibSp':str, 'Parch':str, 'SibSp':int})
data.head()

def to_int_01(x):
    try:
        return int(float(x))
    except (TypeError, ValueError):
        return None
    
data['Survived'] = data['Survived'].apply(to_int_01)

# %% [markdown]
# 看上去一样？检查一下dtypes

# %%
data.dtypes
# Out:
# Age             float64
# Cabin            object
# Embarked         object
# Fare            float64
# Name             object
# Parch            object
# PassengerId       int64
# Pclass           object
# Sex              object
# SibSp             int32
# Survived        float64
# Ticket           object
# dataset_name     object
# dtype: object

# %% [markdown]
# 接下来处理Ticket， 对每一个取值进行分析。

# %%
s = "21171 dasdas dasdad"


def ticket_analysis(s, unexpects):
    try:
        if s.startswith('STON/O 2.'):
            return 'STON/O 2.', s[-7]
        
        if s.startswith('LINE'):
            return 'LINE', None
        
        if s.startswith('SC/AH Basle'):
            return 'SC/AH Basle', None
        
        splitted = s.split(' ')

        ticket_type = None
        ticket_number = None
        if len(splitted) == 1:
            ticket_number = int(splitted[0])
        elif len(splitted) == 2:
            ticket_type = [splitted[0], splitted[1]]
        else:
            raise ValueError
        return ticket_type, ticket_number
    except:
        unexpects.append(s)
        return None, None

# %%
unexpects = []
data['Ticket'].apply(lambda s:ticket_analysis(s, unexpects))
# Out:
# 0                ([A/5, 21171], None)
# 1                 ([PC, 17599], None)
# 2         ([STON/O2., 3101282], None)
# 3                      (None, 113803)
# 4                      (None, 373450)
# 5                      (None, 330877)
# 6                       (None, 17463)
# 7                      (None, 349909)
# 8                      (None, 347742)
# 9                      (None, 237736)
# 10                 ([PP, 9549], None)
# 11                     (None, 113783)
# 12               ([A/5., 2151], None)
# 13                     (None, 347082)
# 14                     (None, 350406)
# 15                     (None, 248706)
# 16                     (None, 382652)
# 17                     (None, 244373)
# 18                     (None, 345763)
# 19                       (None, 2649)
# 20                     (None, 239865)
# 21                     (None, 248698)
# 22                     (None, 330923)
# 23                     (None, 113788)
# 24                     (None, 349909)
# 25                     (None, 347077)
# 26                       (None, 2631)
# 27                      (None, 19950)
# 28                     (None, 330959)
# 29                     (None, 349216)
#                     ...
# 1279                   (None, 364858)
# 1280                   (None, 349909)
# 1281                    (None, 12749)
# 1282              ([PC, 17592], None)
# 1283             ([C.A., 2673], None)
# 1284            ([C.A., 30769], None)
# 1285                   (None, 315153)
# 1286                    (None, 13695)
# 1287                   (None, 371109)
# 1288                    (None, 13567)
# 1289                   (None, 347065)
# 1290                    (None, 21332)
# 1291                    (None, 36928)
# 1292                    (None, 28664)
# 1293                   (None, 112378)
# 1294                   (None, 113059)
# 1295                    (None, 17765)
# 1296         ([SC/PARIS, 2166], None)
# 1297                    (None, 28666)
# 1298                   (None, 113503)
# 1299                   (None, 334915)
# 1300    ([SOTON/O.Q., 3101315], None)
# 1301                   (None, 365237)
# 1302                    (None, 19928)
# 1303                   (None, 347086)
# 1304             ([A.5., 3236], None)
# 1305              ([PC, 17758], None)
# 1306    ([SOTON/O.Q., 3101262], None)
# 1307                   (None, 359309)
# 1308                     (None, 2668)
# Name: Ticket, Length: 1309, dtype: object

# %%
def ticket_analysis(s, unexpects):
    try:
        if ',' in s:
            splitted = s.split(',')
            return split[0], split[1]
        
        if s.startswith('STON/O 2.'):
            return 'STON/O 2.', s[-7]
        
        if s.startswith('LINE'):
            return 'LINE', None
        
        if s.startswith('SC/AH Basle'):
            return 'SC/AH Basle', None
        
        splitted = s.split(' ')

        ticket_type = None
        ticket_number = None
        if len(splitted) == 1:
            ticket_number = int(splitted[0])
        elif len(splitted) == 2:
            ticket_type = splitted[0]
            ticket_number = splitted[1]
        else:
            raise ValueError
        return ticket_type, ticket_number
    except:
        unexpects.append(s)
        return None, None

# %%
unexpects = []
data[['tickket_type', 'tickket_number']] = data['Ticket'].apply(lambda s:Series(ticket_analysis(s, unexpects)))
data
# Out:
#        Age        Cabin Embarked      Fare  \
# 0     22.0          NaN        S    7.2500
# 1     38.0          C85        C   71.2833
# 2     26.0          NaN        S    7.9250
# 3     35.0         C123        S   53.1000
# 4     35.0          NaN        S    8.0500
# 5      NaN          NaN        Q    8.4583
# 6     54.0          E46        S   51.8625
# 7      2.0          NaN        S   21.0750
# 8     27.0          NaN        S   11.1333
# 9     14.0          NaN        C   30.0708
# 10     4.0           G6        S   16.7000
# 11    58.0         C103        S   26.5500
# 12    20.0          NaN        S    8.0500
# 13    39.0          NaN        S   31.2750
# 14    14.0          NaN        S    7.8542
# 15    55.0          NaN        S   16.0000
# 16     2.0          NaN        Q   29.1250
# 17     NaN          NaN        S   13.0000
# 18    31.0          NaN        S   18.0000
# 19     NaN          NaN        C    7.2250
# 20    35.0          NaN        S   26.0000
# 21    34.0          D56        S   13.0000
# 22    15.0          NaN        Q    8.0292
# 23    28.0           A6        S   35.5000
# 24     8.0          NaN        S   21.0750
# 25    38.0          NaN        S   31.3875
# 26     NaN          NaN        C    7.2250
# 27    19.0  C23 C25 C27        S  263.0000
# 28     NaN          NaN        Q    7.8792
# 29     NaN          NaN        S    7.8958
# ...    ...          ...      ...       ...
# 1279  21.0          NaN        Q    7.7500
# 1280   6.0          NaN        S   21.0750
# 1281  23.0          B24        S   93.5000
# 1282  51.0          D28        S   39.4000
# 1283  13.0          NaN        S   20.2500
# 1284  47.0          NaN        S   10.5000
# 1285  29.0          NaN        S   22.0250
# 1286  18.0          C31        S   60.0000
# 1287  24.0          NaN        Q    7.2500
# 1288  48.0          B41        C   79.2000
# 1289  22.0          NaN        S    7.7750
# 1290  31.0          NaN        Q    7.7333
# 1291  30.0           C7        S  164.8667
# 1292  38.0          NaN        S   21.0000
# 1293  22.0          NaN        C   59.4000
# 1294  17.0          NaN        S   47.1000
# 1295  43.0          D40        C   27.7208
# 1296  20.0          D38        C   13.8625
# 1297  23.0          NaN        S   10.5000
# 1298  50.0          C80        C  211.5000
# 1299   NaN          NaN        Q    7.7208
# 1300   3.0          NaN        S   13.7750
# 1301   NaN          NaN        Q    7.7500
# 1302  37.0          C78        Q   90.0000
# 1303  28.0          NaN        S    7.7750
# 1304   NaN          NaN        S    8.0500
# 1305  39.0         C105        C  108.9000
# 1306  38.5          NaN        S    7.2500
# 1307   NaN          NaN        S    8.0500
# 1308   NaN          NaN        C   22.3583
#
#                                                    Name Parch  PassengerId  \
# 0                               Braund, Mr. Owen Harris     0            1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...     0            2
# 2                                Heikkinen, Miss. Laina     0            3
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)     0            4
# 4                              Allen, Mr. William Henry     0            5
# 5                                      Moran, Mr. James     0            6
# 6                               McCarthy, Mr. Timothy J     0            7
# 7                        Palsson, Master. Gosta Leonard     1            8
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)     2            9
# 9                   Nasser, Mrs. Nicholas (Adele Achem)     0           10
# 10                      Sandstrom, Miss. Marguerite Rut     1           11
# 11                             Bonnell, Miss. Elizabeth     0           12
# 12                       Saundercock, Mr. William Henry     0           13
# 13                          Andersson, Mr. Anders Johan     5           14
# 14                 Vestrom, Miss. Hulda Amanda Adolfina     0           15
# 15                     Hewlett, Mrs. (Mary D Kingcome)      0           16
# 16                                 Rice, Master. Eugene     1           17
# 17                         Williams, Mr. Charles Eugene     0           18
# 18    Vander Planke, Mrs. Julius (Emelia Maria Vande...     0           19
# 19                              Masselmani, Mrs. Fatima     0           20
# 20                                 Fynney, Mr. Joseph J     0           21
# 21                                Beesley, Mr. Lawrence     0           22
# 22                          McGowan, Miss. Anna "Annie"     0           23
# 23                         Sloper, Mr. William Thompson     0           24
# 24                        Palsson, Miss. Torborg Danira     1           25
# 25    Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...     5           26
# 26                              Emir, Mr. Farred Chehab     0           27
# 27                       Fortune, Mr. Charles Alexander     2           28
# 28                        O'Dwyer, Miss. Ellen "Nellie"     0           29
# 29                                  Todoroff, Mr. Lalio     0           30
# ...                                                 ...   ...          ...
# 1279                               Canavan, Mr. Patrick     0         1280
# 1280                        Palsson, Master. Paul Folke     1         1281
# 1281                         Payne, Mr. Vivian Ponsonby     0         1282
# 1282     Lines, Mrs. Ernest H (Elizabeth Lindsey James)     1         1283
# 1283                      Abbott, Master. Eugene Joseph     2         1284
# 1284                               Gilbert, Mr. William     0         1285
# 1285                           Kink-Heilmann, Mr. Anton     1         1286
# 1286     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)     0         1287
# 1287                               Colbert, Mr. Patrick     0         1288
# 1288  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...     1         1289
# 1289                     Larsson-Rondberg, Mr. Edvard A     0         1290
# 1290                           Conlon, Mr. Thomas Henry     0         1291
# 1291                            Bonnell, Miss. Caroline     0         1292
# 1292                                    Gale, Mr. Harry     0         1293
# 1293                     Gibson, Miss. Dorothy Winifred     1         1294
# 1294                             Carrau, Mr. Jose Pedro     0         1295
# 1295                       Frauenthal, Mr. Isaac Gerald     0         1296
# 1296       Nourney, Mr. Alfred (Baron von Drachstedt")"     0         1297
# 1297                          Ware, Mr. William Jeffery     0         1298
# 1298                         Widener, Mr. George Dunton     1         1299
# 1299                    Riordan, Miss. Johanna Hannah""     0         1300
# 1300                          Peacock, Miss. Treasteall     1         1301
# 1301                             Naughton, Miss. Hannah     0         1302
# 1302    Minahan, Mrs. William Edward (Lillian E Thorpe)     0         1303
# 1303                     Henriksson, Miss. Jenny Lovisa     0         1304
# 1304                                 Spector, Mr. Woolf     0         1305
# 1305                       Oliva y Ocana, Dona. Fermina     0         1306
# 1306                       Saether, Mr. Simon Sivertsen     0         1307
# 1307                                Ware, Mr. Frederick     0         1308
# 1308                           Peter, Master. Michael J     1         1309
#
#      Pclass     Sex  SibSp  Survived              Ticket dataset_name  \
# 0         3    male      1       0.0           A/5 21171        train
# 1         1  female      1       1.0            PC 17599        train
# 2         3  female      0       1.0    STON/O2. 3101282        train
# 3         1  female      1       1.0              113803        train
# 4         3    male      0       0.0              373450        train
# 5         3    male      0       0.0              330877        train
# 6         1    male      0       0.0               17463        train
# 7         3    male      3       0.0              349909        train
# 8         3  female      0       1.0              347742        train
# 9         2  female      1       1.0              237736        train
# 10        3  female      1       1.0             PP 9549        train
# 11        1  female      0       1.0              113783        train
# 12        3    male      0       0.0           A/5. 2151        train
# 13        3    male      1       0.0              347082        train
# 14        3  female      0       0.0              350406        train
# 15        2  female      0       1.0              248706        train
# 16        3    male      4       0.0              382652        train
# 17        2    male      0       1.0              244373        train
# 18        3  female      1       0.0              345763        train
# 19        3  female      0       1.0                2649        train
# 20        2    male      0       0.0              239865        train
# 21        2    male      0       1.0              248698        train
# 22        3  female      0       1.0              330923        train
# 23        1    male      0       1.0              113788        train
# 24        3  female      3       0.0              349909        train
# 25        3  female      1       1.0              347077        train
# 26        3    male      0       0.0                2631        train
# 27        1    male      3       0.0               19950        train
# 28        3  female      0       1.0              330959        train
# 29        3    male      0       0.0              349216        train
# ...     ...     ...    ...       ...                 ...          ...
# 1279      3    male      0       NaN              364858          oot
# 1280      3    male      3       NaN              349909          oot
# 1281      1    male      0       NaN               12749          oot
# 1282      1  female      0       NaN            PC 17592          oot
# 1283      3    male      0       NaN           C.A. 2673          oot
# 1284      2    male      0       NaN          C.A. 30769          oot
# 1285      3    male      3       NaN              315153          oot
# 1286      1  female      1       NaN               13695          oot
# 1287      3    male      0       NaN              371109          oot
# 1288      1  female      1       NaN               13567          oot
# 1289      3    male      0       NaN              347065          oot
# 1290      3    male      0       NaN               21332          oot
# 1291      1  female      0       NaN               36928          oot
# 1292      2    male      1       NaN               28664          oot
# 1293      1  female      0       NaN              112378          oot
# 1294      1    male      0       NaN              113059          oot
# 1295      1    male      1       NaN               17765          oot
# 1296      2    male      0       NaN       SC/PARIS 2166          oot
# 1297      2    male      1       NaN               28666          oot
# 1298      1    male      1       NaN              113503          oot
# 1299      3  female      0       NaN              334915          oot
# 1300      3  female      1       NaN  SOTON/O.Q. 3101315          oot
# 1301      3  female      0       NaN              365237          oot
# 1302      1  female      1       NaN               19928          oot
# 1303      3  female      0       NaN              347086          oot
# 1304      3    male      0       NaN           A.5. 3236          oot
# 1305      1  female      0       NaN            PC 17758          oot
# 1306      3    male      0       NaN  SOTON/O.Q. 3101262          oot
# 1307      3    male      0       NaN              359309          oot
# 1308      3    male      1       NaN                2668          oot
#
#      tickket_type tickket_number
# 0             A/5          21171
# 1              PC          17599
# 2        STON/O2.        3101282
# 3             NaN         113803
# 4             NaN         373450
# 5             NaN         330877
# 6             NaN          17463
# 7             NaN         349909
# 8             NaN         347742
# 9             NaN         237736
# 10             PP           9549
# 11            NaN         113783
# 12           A/5.           2151
# 13            NaN         347082
# 14            NaN         350406
# 15            NaN         248706
# 16            NaN         382652
# 17            NaN         244373
# 18            NaN         345763
# 19            NaN           2649
# 20            NaN         239865
# 21            NaN         248698
# 22            NaN         330923
# 23            NaN         113788
# 24            NaN         349909
# 25            NaN         347077
# 26            NaN           2631
# 27            NaN          19950
# 28            NaN         330959
# 29            NaN         349216
# ...           ...            ...
# 1279          NaN         364858
# 1280          NaN         349909
# 1281          NaN          12749
# 1282           PC          17592
# 1283         C.A.           2673
# 1284         C.A.          30769
# 1285          NaN         315153
# 1286          NaN          13695
# 1287          NaN         371109
# 1288          NaN          13567
# 1289          NaN         347065
# 1290          NaN          21332
# 1291          NaN          36928
# 1292          NaN          28664
# 1293          NaN         112378
# 1294          NaN         113059
# 1295          NaN          17765
# 1296     SC/PARIS           2166
# 1297          NaN          28666
# 1298          NaN         113503
# 1299          NaN         334915
# 1300   SOTON/O.Q.        3101315
# 1301          NaN         365237
# 1302          NaN          19928
# 1303          NaN         347086
# 1304         A.5.           3236
# 1305           PC          17758
# 1306   SOTON/O.Q.        3101262
# 1307          NaN         359309
# 1308          NaN           2668
#
# [1309 rows x 15 columns]

# %%
def name_analysis(s, unexpects):
    initial_part = None
    title = None
    name_part = None
    other_name_part = None
    nick_name = None
    
    try:
        quote_location = s.find('"')
        if quote_location > 0:
            nick_name = s[(quote_location + 1):-2]
            s = s[(quote_location + 1):]
            
        
        common_location = s.find(',')
        if common_location > 0:
            initial_part = s[:common_location]
            s = s[(common_location+1):]

        left_brace_location = s.find('(')
        if '(' in s:
            other_name_part = s[(left_brace_location+1):-2]
            s = s[:left_brace_location]

        splitted = s.split('.')
        if len(splitted) == 2:
            title = splitted[0].strip()
            name_part = splitted[1].strip()
        else:
            raise ValueError('Unexpected: {}'.format(s))
    except:
        unexpects.append(s)
        
    return initial_part, title, name_part, other_name_part, nick_name

    
data[['name_initial_part', 'name_title', 'name', 'other_name', 'nick_name']] = data['Name'].apply(lambda s:Series(name_analysis(s, unexpects)))
data
# Out:
#        Age        Cabin Embarked      Fare  \
# 0     22.0          NaN        S    7.2500
# 1     38.0          C85        C   71.2833
# 2     26.0          NaN        S    7.9250
# 3     35.0         C123        S   53.1000
# 4     35.0          NaN        S    8.0500
# 5      NaN          NaN        Q    8.4583
# 6     54.0          E46        S   51.8625
# 7      2.0          NaN        S   21.0750
# 8     27.0          NaN        S   11.1333
# 9     14.0          NaN        C   30.0708
# 10     4.0           G6        S   16.7000
# 11    58.0         C103        S   26.5500
# 12    20.0          NaN        S    8.0500
# 13    39.0          NaN        S   31.2750
# 14    14.0          NaN        S    7.8542
# 15    55.0          NaN        S   16.0000
# 16     2.0          NaN        Q   29.1250
# 17     NaN          NaN        S   13.0000
# 18    31.0          NaN        S   18.0000
# 19     NaN          NaN        C    7.2250
# 20    35.0          NaN        S   26.0000
# 21    34.0          D56        S   13.0000
# 22    15.0          NaN        Q    8.0292
# 23    28.0           A6        S   35.5000
# 24     8.0          NaN        S   21.0750
# 25    38.0          NaN        S   31.3875
# 26     NaN          NaN        C    7.2250
# 27    19.0  C23 C25 C27        S  263.0000
# 28     NaN          NaN        Q    7.8792
# 29     NaN          NaN        S    7.8958
# ...    ...          ...      ...       ...
# 1279  21.0          NaN        Q    7.7500
# 1280   6.0          NaN        S   21.0750
# 1281  23.0          B24        S   93.5000
# 1282  51.0          D28        S   39.4000
# 1283  13.0          NaN        S   20.2500
# 1284  47.0          NaN        S   10.5000
# 1285  29.0          NaN        S   22.0250
# 1286  18.0          C31        S   60.0000
# 1287  24.0          NaN        Q    7.2500
# 1288  48.0          B41        C   79.2000
# 1289  22.0          NaN        S    7.7750
# 1290  31.0          NaN        Q    7.7333
# 1291  30.0           C7        S  164.8667
# 1292  38.0          NaN        S   21.0000
# 1293  22.0          NaN        C   59.4000
# 1294  17.0          NaN        S   47.1000
# 1295  43.0          D40        C   27.7208
# 1296  20.0          D38        C   13.8625
# 1297  23.0          NaN        S   10.5000
# 1298  50.0          C80        C  211.5000
# 1299   NaN          NaN        Q    7.7208
# 1300   3.0          NaN        S   13.7750
# 1301   NaN          NaN        Q    7.7500
# 1302  37.0          C78        Q   90.0000
# 1303  28.0          NaN        S    7.7750
# 1304   NaN          NaN        S    8.0500
# 1305  39.0         C105        C  108.9000
# 1306  38.5          NaN        S    7.2500
# 1307   NaN          NaN        S    8.0500
# 1308   NaN          NaN        C   22.3583
#
#                                                    Name Parch  PassengerId  \
# 0                               Braund, Mr. Owen Harris     0            1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...     0            2
# 2                                Heikkinen, Miss. Laina     0            3
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)     0            4
# 4                              Allen, Mr. William Henry     0            5
# 5                                      Moran, Mr. James     0            6
# 6                               McCarthy, Mr. Timothy J     0            7
# 7                        Palsson, Master. Gosta Leonard     1            8
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)     2            9
# 9                   Nasser, Mrs. Nicholas (Adele Achem)     0           10
# 10                      Sandstrom, Miss. Marguerite Rut     1           11
# 11                             Bonnell, Miss. Elizabeth     0           12
# 12                       Saundercock, Mr. William Henry     0           13
# 13                          Andersson, Mr. Anders Johan     5           14
# 14                 Vestrom, Miss. Hulda Amanda Adolfina     0           15
# 15                     Hewlett, Mrs. (Mary D Kingcome)      0           16
# 16                                 Rice, Master. Eugene     1           17
# 17                         Williams, Mr. Charles Eugene     0           18
# 18    Vander Planke, Mrs. Julius (Emelia Maria Vande...     0           19
# 19                              Masselmani, Mrs. Fatima     0           20
# 20                                 Fynney, Mr. Joseph J     0           21
# 21                                Beesley, Mr. Lawrence     0           22
# 22                          McGowan, Miss. Anna "Annie"     0           23
# 23                         Sloper, Mr. William Thompson     0           24
# 24                        Palsson, Miss. Torborg Danira     1           25
# 25    Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...     5           26
# 26                              Emir, Mr. Farred Chehab     0           27
# 27                       Fortune, Mr. Charles Alexander     2           28
# 28                        O'Dwyer, Miss. Ellen "Nellie"     0           29
# 29                                  Todoroff, Mr. Lalio     0           30
# ...                                                 ...   ...          ...
# 1279                               Canavan, Mr. Patrick     0         1280
# 1280                        Palsson, Master. Paul Folke     1         1281
# 1281                         Payne, Mr. Vivian Ponsonby     0         1282
# 1282     Lines, Mrs. Ernest H (Elizabeth Lindsey James)     1         1283
# 1283                      Abbott, Master. Eugene Joseph     2         1284
# 1284                               Gilbert, Mr. William     0         1285
# 1285                           Kink-Heilmann, Mr. Anton     1         1286
# 1286     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)     0         1287
# 1287                               Colbert, Mr. Patrick     0         1288
# 1288  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...     1         1289
# 1289                     Larsson-Rondberg, Mr. Edvard A     0         1290
# 1290                           Conlon, Mr. Thomas Henry     0         1291
# 1291                            Bonnell, Miss. Caroline     0         1292
# 1292                                    Gale, Mr. Harry     0         1293
# 1293                     Gibson, Miss. Dorothy Winifred     1         1294
# 1294                             Carrau, Mr. Jose Pedro     0         1295
# 1295                       Frauenthal, Mr. Isaac Gerald     0         1296
# 1296       Nourney, Mr. Alfred (Baron von Drachstedt")"     0         1297
# 1297                          Ware, Mr. William Jeffery     0         1298
# 1298                         Widener, Mr. George Dunton     1         1299
# 1299                    Riordan, Miss. Johanna Hannah""     0         1300
# 1300                          Peacock, Miss. Treasteall     1         1301
# 1301                             Naughton, Miss. Hannah     0         1302
# 1302    Minahan, Mrs. William Edward (Lillian E Thorpe)     0         1303
# 1303                     Henriksson, Miss. Jenny Lovisa     0         1304
# 1304                                 Spector, Mr. Woolf     0         1305
# 1305                       Oliva y Ocana, Dona. Fermina     0         1306
# 1306                       Saether, Mr. Simon Sivertsen     0         1307
# 1307                                Ware, Mr. Frederick     0         1308
# 1308                           Peter, Master. Michael J     1         1309
#
#      Pclass     Sex  SibSp  Survived              Ticket dataset_name  \
# 0         3    male      1       0.0           A/5 21171        train
# 1         1  female      1       1.0            PC 17599        train
# 2         3  female      0       1.0    STON/O2. 3101282        train
# 3         1  female      1       1.0              113803        train
# 4         3    male      0       0.0              373450        train
# 5         3    male      0       0.0              330877        train
# 6         1    male      0       0.0               17463        train
# 7         3    male      3       0.0              349909        train
# 8         3  female      0       1.0              347742        train
# 9         2  female      1       1.0              237736        train
# 10        3  female      1       1.0             PP 9549        train
# 11        1  female      0       1.0              113783        train
# 12        3    male      0       0.0           A/5. 2151        train
# 13        3    male      1       0.0              347082        train
# 14        3  female      0       0.0              350406        train
# 15        2  female      0       1.0              248706        train
# 16        3    male      4       0.0              382652        train
# 17        2    male      0       1.0              244373        train
# 18        3  female      1       0.0              345763        train
# 19        3  female      0       1.0                2649        train
# 20        2    male      0       0.0              239865        train
# 21        2    male      0       1.0              248698        train
# 22        3  female      0       1.0              330923        train
# 23        1    male      0       1.0              113788        train
# 24        3  female      3       0.0              349909        train
# 25        3  female      1       1.0              347077        train
# 26        3    male      0       0.0                2631        train
# 27        1    male      3       0.0               19950        train
# 28        3  female      0       1.0              330959        train
# 29        3    male      0       0.0              349216        train
# ...     ...     ...    ...       ...                 ...          ...
# 1279      3    male      0       NaN              364858          oot
# 1280      3    male      3       NaN              349909          oot
# 1281      1    male      0       NaN               12749          oot
# 1282      1  female      0       NaN            PC 17592          oot
# 1283      3    male      0       NaN           C.A. 2673          oot
# 1284      2    male      0       NaN          C.A. 30769          oot
# 1285      3    male      3       NaN              315153          oot
# 1286      1  female      1       NaN               13695          oot
# 1287      3    male      0       NaN              371109          oot
# 1288      1  female      1       NaN               13567          oot
# 1289      3    male      0       NaN              347065          oot
# 1290      3    male      0       NaN               21332          oot
# 1291      1  female      0       NaN               36928          oot
# 1292      2    male      1       NaN               28664          oot
# 1293      1  female      0       NaN              112378          oot
# 1294      1    male      0       NaN              113059          oot
# 1295      1    male      1       NaN               17765          oot
# 1296      2    male      0       NaN       SC/PARIS 2166          oot
# 1297      2    male      1       NaN               28666          oot
# 1298      1    male      1       NaN              113503          oot
# 1299      3  female      0       NaN              334915          oot
# 1300      3  female      1       NaN  SOTON/O.Q. 3101315          oot
# 1301      3  female      0       NaN              365237          oot
# 1302      1  female      1       NaN               19928          oot
# 1303      3  female      0       NaN              347086          oot
# 1304      3    male      0       NaN           A.5. 3236          oot
# 1305      1  female      0       NaN            PC 17758          oot
# 1306      3    male      0       NaN  SOTON/O.Q. 3101262          oot
# 1307      3    male      0       NaN              359309          oot
# 1308      3    male      1       NaN                2668          oot
#
#      tickket_type tickket_number name_initial_part name_title  \
# 0             A/5          21171            Braund         Mr
# 1              PC          17599           Cumings        Mrs
# 2        STON/O2.        3101282         Heikkinen       Miss
# 3             NaN         113803          Futrelle        Mrs
# 4             NaN         373450             Allen         Mr
# 5             NaN         330877             Moran         Mr
# 6             NaN          17463          McCarthy         Mr
# 7             NaN         349909           Palsson     Master
# 8             NaN         347742           Johnson        Mrs
# 9             NaN         237736            Nasser        Mrs
# 10             PP           9549         Sandstrom       Miss
# 11            NaN         113783           Bonnell       Miss
# 12           A/5.           2151       Saundercock         Mr
# 13            NaN         347082         Andersson         Mr
# 14            NaN         350406           Vestrom       Miss
# 15            NaN         248706           Hewlett        Mrs
# 16            NaN         382652              Rice     Master
# 17            NaN         244373          Williams         Mr
# 18            NaN         345763     Vander Planke        Mrs
# 19            NaN           2649        Masselmani        Mrs
# 20            NaN         239865            Fynney         Mr
# 21            NaN         248698           Beesley         Mr
# 22            NaN         330923              None       None
# 23            NaN         113788            Sloper         Mr
# 24            NaN         349909           Palsson       Miss
# 25            NaN         347077           Asplund        Mrs
# 26            NaN           2631              Emir         Mr
# 27            NaN          19950           Fortune         Mr
# 28            NaN         330959              None       None
# 29            NaN         349216          Todoroff         Mr
# ...           ...            ...               ...        ...
# 1279          NaN         364858           Canavan         Mr
# 1280          NaN         349909           Palsson     Master
# 1281          NaN          12749             Payne         Mr
# 1282           PC          17592             Lines        Mrs
# 1283         C.A.           2673            Abbott     Master
# 1284         C.A.          30769           Gilbert         Mr
# 1285          NaN         315153     Kink-Heilmann         Mr
# 1286          NaN          13695             Smith        Mrs
# 1287          NaN         371109           Colbert         Mr
# 1288          NaN          13567  Frolicher-Stehli        Mrs
# 1289          NaN         347065  Larsson-Rondberg         Mr
# 1290          NaN          21332            Conlon         Mr
# 1291          NaN          36928           Bonnell       Miss
# 1292          NaN          28664              Gale         Mr
# 1293          NaN         112378            Gibson       Miss
# 1294          NaN         113059            Carrau         Mr
# 1295          NaN          17765        Frauenthal         Mr
# 1296     SC/PARIS           2166              None       None
# 1297          NaN          28666              Ware         Mr
# 1298          NaN         113503           Widener         Mr
# 1299          NaN         334915              None       None
# 1300   SOTON/O.Q.        3101315           Peacock       Miss
# 1301          NaN         365237          Naughton       Miss
# 1302          NaN          19928           Minahan        Mrs
# 1303          NaN         347086        Henriksson       Miss
# 1304         A.5.           3236           Spector         Mr
# 1305           PC          17758     Oliva y Ocana       Dona
# 1306   SOTON/O.Q.        3101262           Saether         Mr
# 1307          NaN         359309              Ware         Mr
# 1308          NaN           2668             Peter     Master
#
#                        name                     other_name nick_name
# 0               Owen Harris                           None      None
# 1              John Bradley          Florence Briggs Thaye      None
# 2                     Laina                           None      None
# 3             Jacques Heath                   Lily May Pee      None
# 4             William Henry                           None      None
# 5                     James                           None      None
# 6                 Timothy J                           None      None
# 7             Gosta Leonard                           None      None
# 8                   Oscar W       Elisabeth Vilhelmina Ber      None
# 9                  Nicholas                     Adele Ache      None
# 10           Marguerite Rut                           None      None
# 11                Elizabeth                           None      None
# 12            William Henry                           None      None
# 13             Anders Johan                           None      None
# 14    Hulda Amanda Adolfina                           None      None
# 15                                         Mary D Kingcome      None
# 16                   Eugene                           None      None
# 17           Charles Eugene                           None      None
# 18                   Julius      Emelia Maria Vandemoortel      None
# 19                   Fatima                           None      None
# 20                 Joseph J                           None      None
# 21                 Lawrence                           None      None
# 22                     None                           None      Anni
# 23         William Thompson                           None      None
# 24           Torborg Danira                           None      None
# 25               Carl Oscar  Selma Augusta Emilia Johansso      None
# 26            Farred Chehab                           None      None
# 27        Charles Alexander                           None      None
# 28                     None                           None     Nelli
# 29                    Lalio                           None      None
# ...                     ...                            ...       ...
# 1279                Patrick                           None      None
# 1280             Paul Folke                           None      None
# 1281        Vivian Ponsonby                           None      None
# 1282               Ernest H         Elizabeth Lindsey Jame      None
# 1283          Eugene Joseph                           None      None
# 1284                William                           None      None
# 1285                  Anton                           None      None
# 1286          Lucien Philip              Mary Eloise Hughe      None
# 1287                Patrick                           None      None
# 1288             Maxmillian     Margaretha Emerentia Stehl      None
# 1289               Edvard A                           None      None
# 1290           Thomas Henry                           None      None
# 1291               Caroline                           None      None
# 1292                  Harry                           None      None
# 1293       Dorothy Winifred                           None      None
# 1294             Jose Pedro                           None      None
# 1295           Isaac Gerald                           None      None
# 1296                   None                           None
# 1297        William Jeffery                           None      None
# 1298          George Dunton                           None      None
# 1299                   None                           None
# 1300             Treasteall                           None      None
# 1301                 Hannah                           None      None
# 1302         William Edward                Lillian E Thorp      None
# 1303           Jenny Lovisa                           None      None
# 1304                  Woolf                           None      None
# 1305                Fermina                           None      None
# 1306        Simon Sivertsen                           None      None
# 1307              Frederick                           None      None
# 1308              Michael J                           None      None
#
# [1309 rows x 20 columns]

# %%
# 可能随机分，没有精确到个人
data[data['Cabin'] == 'B96 B98']
# Out:
#       Age    Cabin Embarked   Fare                                       Name  \
# 390  36.0  B96 B98        S  120.0                 Carter, Mr. William Ernest
# 435  14.0  B96 B98        S  120.0                  Carter, Miss. Lucile Polk
# 763  36.0  B96 B98        S  120.0  Carter, Mrs. William Ernest (Lucile Polk)
# 802  11.0  B96 B98        S  120.0        Carter, Master. William Thornton II
#
#     Parch  PassengerId Pclass     Sex  SibSp  Survived  Ticket dataset_name  \
# 390     2          391      1    male      1       1.0  113760        train
# 435     2          436      1  female      1       1.0  113760        train
# 763     2          764      1  female      1       1.0  113760         test
# 802     2          803      1    male      1       1.0  113760         test
#
#     tickket_type tickket_number name_initial_part name_title  \
# 390          NaN         113760            Carter         Mr
# 435          NaN         113760            Carter       Miss
# 763          NaN         113760            Carter        Mrs
# 802          NaN         113760            Carter     Master
#
#                     name  other_name nick_name
# 390       William Ernest        None      None
# 435          Lucile Polk        None      None
# 763       William Ernest  Lucile Pol      None
# 802  William Thornton II        None      None

# %%
[col for col in list(data.Cabin.dropna().unique()) if ' ' in col]
# Out:
# ['C23 C25 C27',
#  'F G73',
#  'D10 D12',
#  'B58 B60',
#  'F E69',
#  'C22 C26',
#  'B57 B59 B63 B66',
#  'B96 B98',
#  'B51 B53 B55',
#  'F G63',
#  'C62 C64',
#  'B82 B84',
#  'C55 C57',
#  'F E46',
#  'F E57',
#  'E39 E41',
#  'B52 B54 B56']

# %%
from numpy import NaN

# %%
cabin_exploded = data.dropna(subset=['Cabin']).groupby('PassengerId')['Cabin'].apply(lambda s:Series(s.iat[0].split(' '))).reset_index().drop('level_1', axis=1)

def analysis_cabin(s):
    cabin_type = None
    cabin_number = None

    cabin_type = s[0]
    
    try:
        cabin_number = int(s[1:])
    except ValueError:
        pass

    return Series([cabin_type, cabin_number])
    
    
    
cabin_exploded[['cabin_type', 'cabin_number']] = cabin_exploded['Cabin'].apply(analysis_cabin)
cabin_exploded

cabin_exploded.groupby('cabin_type')['cabin_number'].apply(Series.value_counts)
# Out:
# cabin_type
# A           34.0    3
#             18.0    1
#             11.0    1
#             5.0     1
#             7.0     1
#             32.0    1
#             31.0    1
#             19.0    1
#             14.0    1
#             16.0    1
#             10.0    1
#             20.0    1
#             23.0    1
#             26.0    1
#             36.0    1
#             24.0    1
#             21.0    1
#             9.0     1
#             29.0    1
#             6.0     1
# B           63.0    5
#             59.0    5
#             66.0    5
#             57.0    5
#             98.0    4
#             96.0    4
#             51.0    3
#             55.0    3
#             53.0    3
#             60.0    3
#                    ..
# E           8.0     2
#             24.0    2
#             50.0    2
#             25.0    2
#             44.0    2
#             69.0    1
#             36.0    1
#             38.0    1
#             40.0    1
#             10.0    1
#             41.0    1
#             12.0    1
#             39.0    1
#             68.0    1
#             58.0    1
#             77.0    1
#             49.0    1
#             17.0    1
#             45.0    1
#             52.0    1
#             57.0    1
#             60.0    1
#             63.0    1
# F           4.0     4
#             2.0     4
#             33.0    4
#             38.0    1
# G           6.0     5
#             63.0    2
#             73.0    2
# Name: cabin_number, Length: 199, dtype: int64

# %%
def aggregate_cabin(s):
    m = len(s)
    most_frequent = s.value_counts().index[0]
    
    return Series([m, most_frequent], index = ['cabin_count', 'most_possible_cabin'])

cabin_features = cabin_exploded.groupby('PassengerId')['cabin_type'].apply(aggregate_cabin).unstack(level=1)
cabin_features
# Out:
#             cabin_count most_possible_cabin
# PassengerId
# 2                     1                   C
# 4                     1                   C
# 7                     1                   E
# 11                    1                   G
# 12                    1                   C
# 22                    1                   D
# 24                    1                   A
# 28                    3                   C
# 32                    1                   B
# 53                    1                   D
# 55                    1                   B
# 56                    1                   C
# 62                    1                   B
# 63                    1                   C
# 67                    1                   F
# 76                    2                   G
# 89                    3                   C
# 93                    1                   E
# 97                    1                   A
# 98                    2                   D
# 103                   1                   D
# 111                   1                   C
# 119                   2                   B
# 124                   1                   E
# 125                   1                   D
# 129                   2                   E
# 137                   1                   D
# 138                   1                   C
# 140                   1                   B
# 149                   1                   F
# ...                 ...                 ...
# 1193                  1                   D
# 1197                  1                   B
# 1198                  2                   C
# 1200                  1                   B
# 1206                  1                   C
# 1208                  1                   B
# 1213                  2                   E
# 1214                  1                   F
# 1218                  1                   F
# 1223                  1                   A
# 1227                  1                   C
# 1235                  3                   B
# 1242                  2                   D
# 1247                  1                   E
# 1248                  1                   C
# 1256                  1                   E
# 1263                  2                   E
# 1264                  3                   B
# 1266                  1                   A
# 1270                  1                   C
# 1282                  1                   B
# 1283                  1                   D
# 1287                  1                   C
# 1289                  1                   B
# 1292                  1                   C
# 1296                  1                   D
# 1297                  1                   D
# 1299                  1                   C
# 1303                  1                   C
# 1306                  1                   C
#
# [295 rows x 2 columns]

# %%
drops = ['Name', 'Ticket', 'Cabin', 'name_initial_part','name_title','name','other_name','nick_name', 'tickket_type','tickket_number']
data = data.set_index('PassengerId').join(cabin_features, how='outer').drop(drops, axis=1)
data
# Out:
#               Age Embarked      Fare Parch Pclass     Sex  SibSp  Survived  \
# PassengerId
# 1            22.0        S    7.2500     0      3    male      1       0.0
# 2            38.0        C   71.2833     0      1  female      1       1.0
# 3            26.0        S    7.9250     0      3  female      0       1.0
# 4            35.0        S   53.1000     0      1  female      1       1.0
# 5            35.0        S    8.0500     0      3    male      0       0.0
# 6             NaN        Q    8.4583     0      3    male      0       0.0
# 7            54.0        S   51.8625     0      1    male      0       0.0
# 8             2.0        S   21.0750     1      3    male      3       0.0
# 9            27.0        S   11.1333     2      3  female      0       1.0
# 10           14.0        C   30.0708     0      2  female      1       1.0
# 11            4.0        S   16.7000     1      3  female      1       1.0
# 12           58.0        S   26.5500     0      1  female      0       1.0
# 13           20.0        S    8.0500     0      3    male      0       0.0
# 14           39.0        S   31.2750     5      3    male      1       0.0
# 15           14.0        S    7.8542     0      3  female      0       0.0
# 16           55.0        S   16.0000     0      2  female      0       1.0
# 17            2.0        Q   29.1250     1      3    male      4       0.0
# 18            NaN        S   13.0000     0      2    male      0       1.0
# 19           31.0        S   18.0000     0      3  female      1       0.0
# 20            NaN        C    7.2250     0      3  female      0       1.0
# 21           35.0        S   26.0000     0      2    male      0       0.0
# 22           34.0        S   13.0000     0      2    male      0       1.0
# 23           15.0        Q    8.0292     0      3  female      0       1.0
# 24           28.0        S   35.5000     0      1    male      0       1.0
# 25            8.0        S   21.0750     1      3  female      3       0.0
# 26           38.0        S   31.3875     5      3  female      1       1.0
# 27            NaN        C    7.2250     0      3    male      0       0.0
# 28           19.0        S  263.0000     2      1    male      3       0.0
# 29            NaN        Q    7.8792     0      3  female      0       1.0
# 30            NaN        S    7.8958     0      3    male      0       0.0
# ...           ...      ...       ...   ...    ...     ...    ...       ...
# 1280         21.0        Q    7.7500     0      3    male      0       NaN
# 1281          6.0        S   21.0750     1      3    male      3       NaN
# 1282         23.0        S   93.5000     0      1    male      0       NaN
# 1283         51.0        S   39.4000     1      1  female      0       NaN
# 1284         13.0        S   20.2500     2      3    male      0       NaN
# 1285         47.0        S   10.5000     0      2    male      0       NaN
# 1286         29.0        S   22.0250     1      3    male      3       NaN
# 1287         18.0        S   60.0000     0      1  female      1       NaN
# 1288         24.0        Q    7.2500     0      3    male      0       NaN
# 1289         48.0        C   79.2000     1      1  female      1       NaN
# 1290         22.0        S    7.7750     0      3    male      0       NaN
# 1291         31.0        Q    7.7333     0      3    male      0       NaN
# 1292         30.0        S  164.8667     0      1  female      0       NaN
# 1293         38.0        S   21.0000     0      2    male      1       NaN
# 1294         22.0        C   59.4000     1      1  female      0       NaN
# 1295         17.0        S   47.1000     0      1    male      0       NaN
# 1296         43.0        C   27.7208     0      1    male      1       NaN
# 1297         20.0        C   13.8625     0      2    male      0       NaN
# 1298         23.0        S   10.5000     0      2    male      1       NaN
# 1299         50.0        C  211.5000     1      1    male      1       NaN
# 1300          NaN        Q    7.7208     0      3  female      0       NaN
# 1301          3.0        S   13.7750     1      3  female      1       NaN
# 1302          NaN        Q    7.7500     0      3  female      0       NaN
# 1303         37.0        Q   90.0000     0      1  female      1       NaN
# 1304         28.0        S    7.7750     0      3  female      0       NaN
# 1305          NaN        S    8.0500     0      3    male      0       NaN
# 1306         39.0        C  108.9000     0      1  female      0       NaN
# 1307         38.5        S    7.2500     0      3    male      0       NaN
# 1308          NaN        S    8.0500     0      3    male      0       NaN
# 1309          NaN        C   22.3583     1      3    male      1       NaN
#
#             dataset_name cabin_count most_possible_cabin
# PassengerId
# 1                  train         NaN                 NaN
# 2                  train           1                   C
# 3                  train         NaN                 NaN
# 4                  train           1                   C
# 5                  train         NaN                 NaN
# 6                  train         NaN                 NaN
# 7                  train           1                   E
# 8                  train         NaN                 NaN
# 9                  train         NaN                 NaN
# 10                 train         NaN                 NaN
# 11                 train           1                   G
# 12                 train           1                   C
# 13                 train         NaN                 NaN
# 14                 train         NaN                 NaN
# 15                 train         NaN                 NaN
# 16                 train         NaN                 NaN
# 17                 train         NaN                 NaN
# 18                 train         NaN                 NaN
# 19                 train         NaN                 NaN
# 20                 train         NaN                 NaN
# 21                 train         NaN                 NaN
# 22                 train           1                   D
# 23                 train         NaN                 NaN
# 24                 train           1                   A
# 25                 train         NaN                 NaN
# 26                 train         NaN                 NaN
# 27                 train         NaN                 NaN
# 28                 train           3                   C
# 29                 train         NaN                 NaN
# 30                 train         NaN                 NaN
# ...                  ...         ...                 ...
# 1280                 oot         NaN                 NaN
# 1281                 oot         NaN                 NaN
# 1282                 oot           1                   B
# 1283                 oot           1                   D
# 1284                 oot         NaN                 NaN
# 1285                 oot         NaN                 NaN
# 1286                 oot         NaN                 NaN
# 1287                 oot           1                   C
# 1288                 oot         NaN                 NaN
# 1289                 oot           1                   B
# 1290                 oot         NaN                 NaN
# 1291                 oot         NaN                 NaN
# 1292                 oot           1                   C
# 1293                 oot         NaN                 NaN
# 1294                 oot         NaN                 NaN
# 1295                 oot         NaN                 NaN
# 1296                 oot           1                   D
# 1297                 oot           1                   D
# 1298                 oot         NaN                 NaN
# 1299                 oot           1                   C
# 1300                 oot         NaN                 NaN
# 1301                 oot         NaN                 NaN
# 1302                 oot         NaN                 NaN
# 1303                 oot           1                   C
# 1304                 oot         NaN                 NaN
# 1305                 oot         NaN                 NaN
# 1306                 oot           1                   C
# 1307                 oot         NaN                 NaN
# 1308                 oot         NaN                 NaN
# 1309                 oot         NaN                 NaN
#
# [1309 rows x 11 columns]

# %%
data_full = data

# %%
from model_lab.quick_score_card import QuickScoreCard, DataGenerator, build_data_generator

# %%
data_full.to_excel('test_data.xlsx', index=False)

# %%
data = pd.read_excel('test_data.xlsx')
data['Survived'] = data['Survived']


label_col_name = 'Survived'
dataset_col_name = 'dataset_name'

train_dataset_name = 'train'
oot_dataset_name = 'oot'
test_dataset_names = ['test']

data_generator = build_data_generator(
    data,
    label_col_name,
    dataset_col_name,
    train_dataset_name,
    oot_dataset_name,
    test_dataset_names
)


trainer = QuickScoreCard(data_generator)
trainer.run()
# Out:
# Doing task encoder_training ...
# ---------------------------------------------------------------------------
# RuntimeWarning                            Traceback (most recent call last)
# <ipython-input-20-d3af4409ec1f> in <module>()
#      21
#      22 trainer = QuickScoreCard(data_generator)
# ---> 23 trainer.run()
#
# C:\Users\yademan\jupyter notebook\titanic\model_lab\quick_score_card.py in run(self)
#     414             if not self.skipping[task_name]:
#     415                 print('Doing task {} ...'.format(task_name))
# --> 416                 task_method(self)
#     417             else:
#     418                 print('Skip task {} ...'.format(task_name))
#
# C:\Users\yademan\jupyter notebook\titanic\model_lab\quick_score_card.py in _train_feature_encoder(self)
#     450         label = train_data_set.get_label()
#     451
# --> 452         self.score_card_encoder.train(features, label)
#     453
#     454         self._turn_off_encoder_training()
#
# C:\Users\yademan\jupyter notebook\titanic\model_lab\quick_score_card.py in train(self, features, y)
#     316         ivs = []
#     317         for column_name in binned_features.columns:
# --> 318             summary, iv = summarize_categorical(binned_features[column_name], y)
#     319             summary.index = summary.index.astype(object)
#     320
#
# C:\Users\yademan\jupyter notebook\titanic\model_lab\mapper.py in summarize_categorical(x, y, inf_woe)
#     316     summary_df['positive_rate'] = summary_df['n_positive'] / summary_df['n']
#     317
# --> 318     summary_df['woe'] = log(summary_df['positive_percent_across_category'] / summary_df['negative_percent_across_category'])
#     319     summary_df.loc[summary_df['woe'] == infty, 'woe'] = inf_woe
#     320     summary_df.loc[summary_df['woe'] == -infty, 'woe'] = -inf_woe
#
# RuntimeWarning: divide by zero encountered in log
