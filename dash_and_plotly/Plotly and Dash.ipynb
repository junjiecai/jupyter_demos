# %% [markdown]
# # 我们为什么需要Plotly和Dash

# %% [markdown]
# Plotly和dash以一种便捷的方式提供**带交互**的可视化效果

# %% [markdown]
# ## plotly的例子

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
import plotly.express as px
df = px.data.gapminder()

figure = px.scatter(
    df, 
    x = 'gdpPercap',
    y = 'lifeExp',
    size = df['pop']**0.75,
    size_max=50,
    color = 'country',
    animation_frame = 'year',
    height = 800,
    width = 1200,
    range_x = [1, 50000],
    range_y = [1, 100],
    title='Plotly Demo'
)

# %%
figure
# Out:
# <div>
#
#
#             <div id="c21020fd-5c60-457b-ab1f-8410e9670883" class="plotly-graph-div" style="height:800px; width:1200px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c21020fd-5c60-457b-ab1f-8410e9670883")) {
#                     Plotly.newPlot(
#                         'c21020fd-5c60-457b-ab1f-8410e9670883',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Afghanistan<br>year=1952<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>size=%{marker.size}", "legendgroup": "Afghanistan", "marker": {"color": "#636efa", "size": [156383.27577380376], "sizemode": "area", "sizeref": 2767.9951232427234, "symbol": "circle"}, "mode": "markers", "name": "Afghanistan", "showlegend": true, "type": "scatter", "x": [779.4453145], "xaxis": "x", "y": [28.801], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Albania<br>year=1952<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>size=%{marker.size}", "legendgroup": "Albania", "marker": {"color": "#EF553B", "size": [38114.74857252988], "sizemode": "area", "sizeref": 2767.9951232427234, "symbol": "circle"}, "mode": "markers", "name": "Albania", "showlegend": true, "type": "scatter", "x": [1601.056136], "xaxis": "x", "y": [55.23], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Algeria<br>year=1952<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>size=%{marker.size}", "legendgroup": "Algeria", "marker": {"color": "#00cc96", "size": [168129.6502744423], "sizemode": "area", "sizeref": 2767.9951232427234, "symbol": "circle"}, "mode": "markers", "name": "Algeria", "showlegend": true, "type": "scatter", "x": [2449.008185], "xaxis": "x", "y": [43.077], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Angola<br>year=1952<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>size=%{marker.size}", "legendgroup": "Angola", "marker": {"color": "#ab63fa", "size": [93307.50053706173], "sizemode": "area", "sizeref": 2767.9951232427234, "symbol": "circle"}, "mode": "markers", "name": "Angola", "showlegend": true, "type": "scatter", "x": [3520.610273], "xaxis": "x", "y": [30.015], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Argentina<br>year=1952<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>size=%{marker.size}", "legendgroup": "Argentina", "marker": {"color": "#FFA15A", "size": [274928.7632456748], "sizemode": "area", "sizeref": 2767.9951232427234, "symbol": "circle"}, "mode": "markers", "name": "Argentina", "showlegend": true, "type": "scatter", "x": [5911.315053], "xaxis": "x", "y": [62.485], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Australia<br>year=1952<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>size=%{marker.size}", "legendgroup": "Australia", "marker": {"color": "#19d3f3", "size": [160070.1152646136], "sizemode": "area", "sizeref": 2767.9951232427234, "symbol": "circle"}, "mode": "markers", "name": "Australia", "showlegend": true, "type": "scatter", "x": [10039.595640000001], "xaxis": "x", "y": [69.12], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Austria<br>year=1952<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>size=%{marker.size}", "legendgroup": "Austria", "marker": {"color": "#FF6692", "size": [135034.63959019707], "sizemode": "area", "sizeref": 2767.9951232427234, "symbol": "circle"}, "mode": "markers", "name": "Austria", "showlegend": true, "type": "scatter", "x": [6137.076492], "xaxis": "x", "y": [66.8], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Bahrain<br>year=1952<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>size=%{marker.size}", "legendgroup": "Bahrain", "marker": {"color": "#B6E880", "size": [6465.423695353357], "sizemode": "area", "sizeref": 2767.9951232427234, "symbol": "circle"}, "mode": "markers", "name": "Bahrain", "showlegend": true, "type": "scatter", "x": [9867.084765000001], "xaxis": "x", "y": [50.93899999999999], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Bangladesh<br>year=1952<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>size=%{marker.size}", "legendgroup": "Bangladesh", "marker": {"color": "#FF97FF", "size": [566615.3750779538], "sizemode": "area", "sizeref": 2767.9951232427234, "symbol": "circle"}, "mode": "markers", "name": "Bangladesh", "showlegend": true, "type": "scatter", "x": [684.2441716], "xaxis": "x", "y ...

# %% [markdown]
# 官方提供[的更多例子](https://plotly.com/python/)

# %% [markdown]
# ## Dash的例子

# %% [markdown]
# Dash官方提供的[展示](https://dash-gallery.plotly.host/Portal/)

# %% [markdown]
# # 为什我们需要掌握可视化和交互效果的技术

# %% [markdown]
# ## 可视化的意义
#
# 对于大部分人，直观的可视化结果可以更容易传达数据中蕴含的信息（数值分布，关系等）

# %% [markdown]
# ## 交互效果的意义

# %% [markdown]
# 提升技术人员和使用人员双方的体验
# * 一次制作，使用时可以根据实际情况探索
# * 如果是静态图方案，要么频繁的修改，要么事先生成大量静态图。对技术人员和使用人员体验都很糟

# %% [markdown]
# ## 营销展示意义
# * 良好的可视化和交互作品，可以让合作方感觉我们的工作有更高的可信度，专业度与质量
# * 售前部门也可以直接用于和用户展示

# %% [markdown]
# # 为什推荐Plotly
# python有名的可视化库还有matplotlib, seaborn, bohek等，为什么选择plotly和dash？

# %% [markdown]
# ## 展示效果
#
# matplotlib, seaborn都是静态可视化解决方案，无法提供交互能力
#
# 且从展示效果看，大部分效果plotly均可实现
#
# [matplotlib展示](https://matplotlib.org/tutorials/index.html)
#
# [seaborn展示](https://matplotlib.org/tutorials/index.html)
#
#
# bohek的展示的视觉效果和交互效果也不及plotly和dash
#
# [bohek展示](https://docs.bokeh.org/en/latest/docs/gallery.html)

# %% [markdown]
# ## 和前端技术的无缝对接

# %% [markdown]
# plotly和dash可以很方便的和专业的前端开发技术栈对接

# %% [markdown]
# * python生成的plotly图可以转化成页面可识别的json(浏览器中交给plotly.js库渲染)
# * 可以利用react丰富Dash的组件
#
# bohek脱离python很难和前端技术整合

# %%
from plotly import graph_objects as go
import json

# %%
fig = px.line(
    x = [1,2,3],
    y = [2,3,5]
)

fig.to_json() # 将json copy入html测试
# Out:
# '{"data":[{"hoverlabel":{"namelength":0},"hovertemplate":"x=%{x}<br>y=%{y}","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"","showlegend":false,"type":"scatter","x":[1,2,3],"xaxis":"x","y":[2,3,5],"yaxis":"y"}],"layout":{"legend":{"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergl"}],"scattermapbox":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermapbox"}],"scatterpolar":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatterpolar"}],"scatterpolargl":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatterpolargl"}],"scatterternary":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatterte ...

# %% [markdown]
# ## 优势总结

# %% [markdown]
# 仅凭以上两点已经足够让plotly + dash脱颖而出，总结下plotly的优势
# * 自带美观的样式
# * 自带丰富的交互效果
# * 可进可退，可根据需要选择对应复杂度的应用方案
#     * 静态图(jpeg, png等)
#     * 独立的交互图(html)
#     * 多组件交互Dashboard(需要部署)
#     * 配合专业的前端开发技术栈(需要部署)

# %% [markdown]
# # 绘图方式

# %% [markdown]
# ## 利用```express```组件

# %% [markdown]
# express提供了high level的绘图接口，是最方便的使用方式

# %%
px.line(
    x = [1,2,3, 2,3,4], 
    y = [2,3,1,2,3,4], 
    facet_col=['a','a', 'a', 'b', 'b', 'b'], 
    title='基本绘图', 
    width=800, 
    height=400
)
# Out:
# <div>
#
#
#             <div id="b4f8e539-4b95-47a2-9de1-f981290bed32" class="plotly-graph-div" style="height:400px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b4f8e539-4b95-47a2-9de1-f981290bed32")) {
#                     Plotly.newPlot(
#                         'b4f8e539-4b95-47a2-9de1-f981290bed32',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "facet_col=a<br>x=%{x}<br>y=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": [1, 2, 3], "xaxis": "x", "y": [2, 3, 1], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "facet_col=b<br>x=%{x}<br>y=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": [2, 3, 4], "xaxis": "x2", "y": [2, 3, 4], "yaxis": "y2"}],
#                         {"annotations": [{"font": {}, "showarrow": false, "text": "facet_col=a", "x": 0.245, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {}, "showarrow": false, "text": "facet_col=b", "x": 0.755, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}], "height": 400, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type" ...

# %% [markdown]
# ## 利用```graph_objects```组件

# %% [markdown]
# ```express```模块的缺点是灵活性有限，如果需要对绘图进行更细致的调整，可以利用```graph_objects```模块。后面的讲解也主要围绕这种模式。

# %%
from plotly import graph_objects as go
from plotly.subplots import make_subplots

# %%
fig = make_subplots(rows=2, cols=1, shared_xaxes=True, row_heights=[0.7, 0.3])

fig.add_trace(    
    go.Scatter(x=[1,2,3], y=[2,3,4], name='A'),
    row=1, col=1
)
fig.add_trace(    
    go.Scatter(x=[1,2,3], y=[3,2,3], name='B'),
    row=1, col=1
)


fig.add_trace(
    go.Bar(x=[1,2,3], y=[2,3,4]),
    row=2, col=1
)
# Out:
# <div>
#
#
#             <div id="72756f2b-4b42-40a3-a05d-e63c27d1bec5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("72756f2b-4b42-40a3-a05d-e63c27d1bec5")) {
#                     Plotly.newPlot(
#                         '72756f2b-4b42-40a3-a05d-e63c27d1bec5',
#                         [{"name": "A", "type": "scatter", "x": [1, 2, 3], "xaxis": "x", "y": [2, 3, 4], "yaxis": "y"}, {"name": "B", "type": "scatter", "x": [1, 2, 3], "xaxis": "x", "y": [3, 2, 3], "yaxis": "y"}, {"type": "bar", "x": [1, 2, 3], "xaxis": "x2", "y": [2, 3, 4], "yaxis": "y2"}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %% [markdown]
# # 基于dict创建Figure

# %% [markdown]
# 也可以基于dict信息直接创建Figure，似乎很少有使用场景

# %%
import plotly.graph_objects as go
fig = go.Figure({
    "data": [{"type": "bar",
              "x": [1, 2, 3],
              "y": [1, 3, 2]}],
    "layout": {"title": {"text": "A Bar Chart"}}
})
fig
# Out:
# <div>
#
#
#             <div id="3eac8737-e43f-4689-9618-4c013a6a3f25" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3eac8737-e43f-4689-9618-4c013a6a3f25")) {
#                     Plotly.newPlot(
#                         '3eac8737-e43f-4689-9618-4c013a6a3f25',
#                         [{"type": "bar", "x": [1, 2, 3], "y": [1, 3, 2]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %% [markdown]
# # 如何了解应该怎么配置图形？
#
# 例如，想把线形改成虚线，应该怎么配置呢？
#
# ## 查询官方文档
#
# * 官方的[API refernence](https://plotly.com/python/reference/)
#
# * 官方的[Figure Reference](https://plotly.com/python/reference/)
#
# ## 善用google
# google ```plotly line dash```
#
# ## 看看object的结构

# %%
fig = px.line(x=[1,2,3], y= [2,3,4])

# %%
fig['data']
# Out:
# (Scatter({
#      'hoverlabel': {'namelength': 0},
#      'hovertemplate': 'x=%{x}<br>y=%{y}',
#      'legendgroup': '',
#      'line': {'color': '#636efa', 'dash': 'solid'},
#      'mode': 'lines',
#      'name': '',
#      'showlegend': False,
#      'x': array([1, 2, 3]),
#      'xaxis': 'x',
#      'y': array([2, 3, 4]),
#      'yaxis': 'y'
#  }),)

# %%
fig['layout']
# Out:
# Layout({
#     'legend': {'tracegroupgap': 0},
#     'margin': {'t': 60},
#     'template': '...',
#     'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'x'}},
#     'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'y'}}
# })

# %% [markdown]
# 可以找到```line-dash```的路径

# %%
fig.update_traces(
    {'line':{'dash':'dot'}}
)
# Out:
# <div>
#
#
#             <div id="aa5e116e-f1d8-46a1-8b58-53547b7a6e10" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("aa5e116e-f1d8-46a1-8b58-53547b7a6e10")) {
#                     Plotly.newPlot(
#                         'aa5e116e-f1d8-46a1-8b58-53547b7a6e10',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "dot"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": [1, 2, 3], "xaxis": "x", "y": [2, 3, 4], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpola ...

# %% [markdown]
# # Takehome
# * 浏览plotly python[官方文档](https://plotly.com/python)，主要目的
#     * 大致plotly提供了哪些绘图类型
#     * 大致了解plotly有哪些可配置的项目

# %% [markdown]
# # 下期预告

# %% [markdown]
# * 自己实际工作遇到的plotly一些重要细节
# * Dash的使用

# %% [markdown]
# # 反馈

# %% [markdown]
# ![二维码](qrcode.jpg)
